# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from bs4 import BeautifulSoup as bs
import math
from getpass import getpass
import random
import sys, traceback

# %% [markdown]
# # Welcome to ArcadaCade
#
# ## We offer three different games:
# -***Rock paper scissors*** <br>
# -***The guessing game*** <br>
# -***OptimusPRIME*** <br>
#
#
# ### Please run the cell below to begin!
#
# #### Disclaimer, exit code not fully working for all games

# %%
def optimus(prime):
    '''Takes in a number 'prime', returns True or False depending on if inputed number is a prime number or not '''
    for i in range(2,int(math.sqrt(prime))+1):
        if (prime%i) == 0:
          return False
    return True

playing = True

def main():
    try:
        while (playing == True):
            choice = input("Menu: \nIf you wish to play RPS, press 1\nIf you wish to play The guessing game, press 2\nIf you wish to play OptimusPRIME, press 3\nIf you wish to exit, press q\n\n")

            if (choice == "1"):
                    while True:
                        p1in = getpass("player one input: ")
                        p2in = getpass("player two input: ")

                        if p1in == p2in:
                            print("DRAW")
                            play_again = input("Play again? (y/n): ")
                            if play_again.lower() != "y":
                                    sys.exit(0)

                        if p1in == "sax" and p2in == "påse":
                            print("PLAYER 1 WINS")
                            play_again = input("Play again? (y/n): ")
                            if play_again.lower() != "y":
                                    sys.exit(0)

                        if p1in == "sax" and p2in == "sten":
                            print("PLAYER 2 WINS")
                            play_again = input("Play again? (y/n): ")
                            if play_again.lower() != "y":
                                    sys.exit(0)

                        if p1in == "sten" and p2in == "sax":
                            print("PLAYER 1 WINS")
                            play_again = input("Play again? (y/n): ")
                            if play_again.lower() != "y":
                                    sys.exit(0)

                        if p1in == "sten" and p2in == "påse":
                            print("PLAYER 2 WINS")
                            play_again = input("Play again? (y/n): ")
                            if play_again.lower() != "y":
                                    sys.exit(0)

                        if p1in == "påse" and p2in == "sten":
                            print("PLAYER 1 WINS")
                            play_again = input("Play again? (y/n): ")
                            if play_again.lower() != "y":
                                    sys.exit(0)

                        if p1in == "påse" and p2in == "sax":
                            print("PLAYER 2 WINS")
                            play_again = input("Play again? (y/n): ")
                            if play_again.lower() != "y":
                                    sys.exit(0)


            if (choice == "2"):
                compChoice = random.randint(0, 9)
                counter = 1
                while True:


                        print("Var god och gö en gissning: ")
                        userIn = int(input())

                        int(userIn)
                        type(userIn)

                        if userIn > compChoice:
                            print("lower")
                            counter = counter + 1
                        if userIn < compChoice:
                            print("higher")
                            counter = counter + 1
                        if userIn == compChoice:
                            print("Correct, it took you: ", counter, "guesses")
                            play_again = input("Play again? (y/n): ")
                            if play_again.lower() != "y":
                                    break

            if (choice == "3"):
                prime = int(input("Type in a number you wish to OPTIMUSPRIME, If the program returns true, it means your number is a PRIME number\n and if it returns false, your number is not\n\n"))
                anwser = optimus(prime)
                print(anwser)
            elif (choice == "q" or "Q"):
                        print("Bye!")
                        break
                
    except Exception:
        traceback.print_exc(file=sys.stdout)
    sys.exit(0)
if __name__ == "__main__":
    main()
# Out:
# Menu:
# If you wish to play RPS, press 1
# If you wish to play The guessing game, press 2
# If you wish to play OptimusPRIME, press 3
# If you wish to exit, press q
#
# 2
# Var god och gö en gissning:
# 1
# higher
# Var god och gö en gissning:
# 2
# higher
# Var god och gö en gissning:
# 3
# higher
# Var god och gö en gissning:
# 4
# higher
# Var god och gö en gissning:
# 5
# higher
# Var god och gö en gissning:
# 6
# higher
# Var god och gö en gissning:
# 7
# higher
# Var god och gö en gissning:
# 8
# higher
# Var god och gö en gissning:
# 9
# Correct, it took you:  9 guesses

# %%
optimus?
